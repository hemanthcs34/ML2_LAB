# %% [markdown]
# <a href="https://colab.research.google.com/github/hemanthcs34/ML2_LAB/blob/main/find_s_ml2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = [
    ['Sunny', 'Warm', 'Normal', 'Strong', 'Yes'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Yes'],
    ['Rainy', 'Cold', 'High', 'Strong', 'No'],
    ['Sunny', 'Warm', 'High', 'Weak', 'Yes']
]


hypothesis = ['Ø', 'Ø', 'Ø', 'Ø']

for row in data:


    if row[-1] == 'Yes':


        if hypothesis[0] == 'Ø':
            hypothesis = row[:-1]

        else:

            for i in range(len(hypothesis)):


                if hypothesis[i] != row[i]:
                    hypothesis[i] = '?'


print("Final Hypothesis:")
print(hypothesis)
# Out:
# Final Hypothesis:
# ['Sunny', 'Warm', '?', '?']
